# %%
# Installing xlrd package, library for reading data from Excel files

# !pip install xlrd
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pandas as pd
import numpy as np
df =pd.read_excel ('/content/fashion brand details.xlsx', sheet_name='brand details')
df
# Out:
#       brand_id    brand_name
# 0            1           513
# 1            2          109F
# 2            3     20Dresses
# 3            4   250 Designs
# 4            5          3Pin
# ...        ...           ...
# 1015      1016  Ziva Fashion
# 1016      1017        Zivame
# 1017      1018         Ziyaa
# 1018      1019        Zoella
# 1019      1020          Zola
#
# [1020 rows x 2 columns]

# %%
# Convert excel file to CSV
df.to_csv('/content/fashion brand details.csv', index=False)
df
# Out:
#       brand_id    brand_name
# 0            1           513
# 1            2          109F
# 2            3     20Dresses
# 3            4   250 Designs
# 4            5          3Pin
# ...        ...           ...
# 1015      1016  Ziva Fashion
# 1016      1017        Zivame
# 1017      1018         Ziyaa
# 1018      1019        Zoella
# 1019      1020          Zola
#
# [1020 rows x 2 columns]

# %%
# Import Fashion dataset
df1 = pd.read_csv('/content/fashion dataset.csv')
df1
# Out:
#              p_id                                               name   price  \
# 0       1518329.0   Dupatta Bazaar White Embroidered Chiffon Dupatta   899.0
# 1       5829334.0  Roadster Women Mustard Yellow Solid Hooded Swe...  1199.0
# 2      10340119.0  Inddus Peach-Coloured & Beige Unstitched Dress...  5799.0
# 3      10856380.0            SASSAFRAS Women Black Parallel Trousers  1499.0
# 4      12384822.0  Kotty Women Black Wide Leg High-Rise Clean Loo...  1999.0
# ...           ...                                                ...     ...
# 14324  17029604.0  The Chennai Silks Pink & Silver-Toned Floral Z...  3999.0
# 14325  17600212.0  Kinder Kids Girls Blue & Green Printed Foil Pr...  2050.0
# 14326  18159266.0  KLOTTHE Women Green & Black Floral Printed Pal...  1659.0
# 14327  18921114.0             InWeave Women Red Printed A-Line Skirt  2399.0
# 14328  19361058.0      BoStreet Women Navy Blue Tapered Fit Trousers  2599.0
#
# ...

# %%
# Merging both datasets
df1 = pd.read_csv('/content/fashion dataset.csv')
df2 = pd.read_csv('/content/fashion brand details.csv')

df_merged = pd.merge (df1,df2, left_on='brand', right_on='brand_name', how='left')
df_merged
# Out:
#              p_id                                               name   price  \
# 0       1518329.0   Dupatta Bazaar White Embroidered Chiffon Dupatta   899.0
# 1       5829334.0  Roadster Women Mustard Yellow Solid Hooded Swe...  1199.0
# 2      10340119.0  Inddus Peach-Coloured & Beige Unstitched Dress...  5799.0
# 3      10856380.0            SASSAFRAS Women Black Parallel Trousers  1499.0
# 4      12384822.0  Kotty Women Black Wide Leg High-Rise Clean Loo...  1999.0
# ...           ...                                                ...     ...
# 14324  17029604.0  The Chennai Silks Pink & Silver-Toned Floral Z...  3999.0
# 14325  17600212.0  Kinder Kids Girls Blue & Green Printed Foil Pr...  2050.0
# 14326  18159266.0  KLOTTHE Women Green & Black Floral Printed Pal...  1659.0
# 14327  18921114.0             InWeave Women Red Printed A-Line Skirt  2399.0
# 14328  19361058.0      BoStreet Women Navy Blue Tapered Fit Trousers  2599.0
#
# ...

# %%
# using the 'pandas.DataFrame.to_csv' method used earlier, i saved the merged dataset to a CSV file:

df_merged.to_csv('aaliyahs_merged_fashion_dataset.csv', index=False)
df_merged
# Out:
#              p_id                                               name   price  \
# 0       1518329.0   Dupatta Bazaar White Embroidered Chiffon Dupatta   899.0
# 1       5829334.0  Roadster Women Mustard Yellow Solid Hooded Swe...  1199.0
# 2      10340119.0  Inddus Peach-Coloured & Beige Unstitched Dress...  5799.0
# 3      10856380.0            SASSAFRAS Women Black Parallel Trousers  1499.0
# 4      12384822.0  Kotty Women Black Wide Leg High-Rise Clean Loo...  1999.0
# ...           ...                                                ...     ...
# 14324  17029604.0  The Chennai Silks Pink & Silver-Toned Floral Z...  3999.0
# 14325  17600212.0  Kinder Kids Girls Blue & Green Printed Foil Pr...  2050.0
# 14326  18159266.0  KLOTTHE Women Green & Black Floral Printed Pal...  1659.0
# 14327  18921114.0             InWeave Women Red Printed A-Line Skirt  2399.0
# 14328  19361058.0      BoStreet Women Navy Blue Tapered Fit Trousers  2599.0
#
# ...

# %%
# To confirm that the current position of our columns, we can print a list of all the
# columns in the dataframe using the df_merged.columns attribute:

print(df_merged.columns)
# Out:
# Index(['p_id', 'name', 'price', 'colour', 'brand', 'ratingCount', 'avg_rating',
#        'description', 'p_attributes', 'brand_id', 'brand_name'],
#       dtype='object')

# %%
# using the 'pandas.DataFrame.pop' and 'pandas.DataFrame.insert' method to remove and reposition
# the 'brand_id' column on the dataset

brand_id = df_merged.pop('brand_id')

df_merged.insert(1, 'brand_id', brand_id)

# %%
# To confirm that the column has been moved to our desired position, we can print a list of all the
# columns in the dataframe using the 'df_merged.columns' attribute:

print(df_merged.columns)
# Out:
# Index(['p_id', 'brand_id', 'name', 'price', 'colour', 'brand', 'ratingCount',
#        'avg_rating', 'description', 'p_attributes', 'brand_name'],
#       dtype='object')

# %%
# using the 'pandas.DataFrame.pop' and 'pandas.DataFrame.insert' method to remove and reposition
# the 'brand_name' column on the dataset

brand_name = df_merged.pop('brand_name')

df_merged.insert(2, 'brand_name', brand_name)

# %%
# using the 'pandas.DataFrame.pop' and 'pandas.DataFrame.insert' method to remove and reposition
# the 'brand' column on the dataset

brand = df_merged.pop('brand')

df_merged.insert(3, 'brand', brand)

# %%
# To confirm that the column has been moved to our desired position, we can print a list of all the
# columns in the dataframe using the 'df_merged.columns' attribute:

print(df_merged.columns)
# Out:
# Index(['p_id', 'brand_id', 'brand_name', 'brand', 'name', 'price', 'colour',
#        'ratingCount', 'avg_rating', 'description', 'p_attributes'],
#       dtype='object')

# %%
# print the merged dataset to view our repositioned columns

df_merged
# Out:
#              p_id  brand_id         brand_name              brand  \
# 0       1518329.0     242.0     Dupatta Bazaar     Dupatta Bazaar
# 1       5829334.0     750.0           Roadster           Roadster
# 2      10340119.0     389.0             Inddus             Inddus
# 3      10856380.0       NaN                NaN          SASSAFRAS
# 4      12384822.0     482.0              Kotty              Kotty
# ...           ...       ...                ...                ...
# 14324  17029604.0     880.0  The Chennai Silks  The Chennai Silks
# 14325  17600212.0     471.0        Kinder Kids        Kinder Kids
# 14326  18159266.0       NaN                NaN            KLOTTHE
# 14327  18921114.0       NaN                NaN            InWeave
# 14328  19361058.0       NaN                NaN           BoStreet
#
#                                                     name   price     colour  \
# 0       Dupatta Bazaar White Embroidered Chiffon Dupatta   899.0      White
# ...

# %%
# To clean our dataset, we will delete irrelevant columns, we use the 'pandas.DataFrame.drop' method
#  The columns to be dropped are 'p_id', 'brand_name', 'description', 'p_attributes'

df_merged = df_merged.drop(columns=['p_id', 'brand_name', 'description', 'p_attributes'])
df_merged
# Out:
#        brand_id              brand  \
# 0         242.0     Dupatta Bazaar
# 1         750.0           Roadster
# 2         389.0             Inddus
# 3           NaN          SASSAFRAS
# 4         482.0              Kotty
# ...         ...                ...
# 14324     880.0  The Chennai Silks
# 14325     471.0        Kinder Kids
# 14326       NaN            KLOTTHE
# 14327       NaN            InWeave
# 14328       NaN           BoStreet
#
#                                                     name   price     colour  \
# 0       Dupatta Bazaar White Embroidered Chiffon Dupatta   899.0      White
# 1      Roadster Women Mustard Yellow Solid Hooded Swe...  1199.0    Mustard
# 2      Inddus Peach-Coloured & Beige Unstitched Dress...  5799.0      Peach
# 3                SASSAFRAS Women Black Parallel Trousers  1499.0      Black
# 4      Kotty Women Black Wide Leg High-Rise Clean Loo...  1999.0      Black
# ...                                                  ...     ...        ...
# ...

# %%
# To proceed with cleaninig our dataset, we will need to replace all Null or NaN values with 0, to do this we will be using the
# 'pandas.DataFrame.fillna' method

# Replace NaN values with 0
df_merged = df_merged.fillna(0)
df_merged
# Out:
#        brand_id              brand  \
# 0         242.0     Dupatta Bazaar
# 1         750.0           Roadster
# 2         389.0             Inddus
# 3           0.0          SASSAFRAS
# 4         482.0              Kotty
# ...         ...                ...
# 14324     880.0  The Chennai Silks
# 14325     471.0        Kinder Kids
# 14326       0.0            KLOTTHE
# 14327       0.0            InWeave
# 14328       0.0           BoStreet
#
#                                                     name   price     colour  \
# 0       Dupatta Bazaar White Embroidered Chiffon Dupatta   899.0      White
# 1      Roadster Women Mustard Yellow Solid Hooded Swe...  1199.0    Mustard
# 2      Inddus Peach-Coloured & Beige Unstitched Dress...  5799.0      Peach
# 3                SASSAFRAS Women Black Parallel Trousers  1499.0      Black
# 4      Kotty Women Black Wide Leg High-Rise Clean Loo...  1999.0      Black
# ...                                                  ...     ...        ...
# ...

# %%
# After removing the null and NaN values, we will proceed to removing duplicate rows

df_merged = df_merged.drop_duplicates()
df_merged
# Out:
#        brand_id              brand  \
# 0         242.0     Dupatta Bazaar
# 1         750.0           Roadster
# 2         389.0             Inddus
# 3           0.0          SASSAFRAS
# 4         482.0              Kotty
# ...         ...                ...
# 14324     880.0  The Chennai Silks
# 14325     471.0        Kinder Kids
# 14326       0.0            KLOTTHE
# 14327       0.0            InWeave
# 14328       0.0           BoStreet
#
#                                                     name   price     colour  \
# 0       Dupatta Bazaar White Embroidered Chiffon Dupatta   899.0      White
# 1      Roadster Women Mustard Yellow Solid Hooded Swe...  1199.0    Mustard
# 2      Inddus Peach-Coloured & Beige Unstitched Dress...  5799.0      Peach
# 3                SASSAFRAS Women Black Parallel Trousers  1499.0      Black
# 4      Kotty Women Black Wide Leg High-Rise Clean Loo...  1999.0      Black
# ...                                                  ...     ...        ...
# ...

# %%
# using the 'pandas.DataFrame.to_csv' method to save our cleaned dataset to a CSV file:

df_merged.to_csv('Cleaned_aaliyahs_merged_fashion_dataset.csv', index=False)
df_merged
# Out:
#        brand_id              brand  \
# 0         242.0     Dupatta Bazaar
# 1         750.0           Roadster
# 2         389.0             Inddus
# 3           0.0          SASSAFRAS
# 4         482.0              Kotty
# ...         ...                ...
# 14324     880.0  The Chennai Silks
# 14325     471.0        Kinder Kids
# 14326       0.0            KLOTTHE
# 14327       0.0            InWeave
# 14328       0.0           BoStreet
#
#                                                     name   price     colour  \
# 0       Dupatta Bazaar White Embroidered Chiffon Dupatta   899.0      White
# 1      Roadster Women Mustard Yellow Solid Hooded Swe...  1199.0    Mustard
# 2      Inddus Peach-Coloured & Beige Unstitched Dress...  5799.0      Peach
# 3                SASSAFRAS Women Black Parallel Trousers  1499.0      Black
# 4      Kotty Women Black Wide Leg High-Rise Clean Loo...  1999.0      Black
# ...                                                  ...     ...        ...
# ...

# %%
print(df_merged.columns)
# Out:
# Index(['brand_id', 'brand', 'name', 'price', 'colour', 'ratingCount',
#        'avg_rating'],
#       dtype='object')
